# %%
import json

# %%
# Function to load the data
def load_data(filename):
  with open(filename,"r") as f:
    data = json.load(f)
  return data

# %%
# check if the data loads
data = load_data("..data/cleaned/data.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3692002084.py in <cell line: 0>()
#       1 # check if the data loads
# ----> 2 data = load_data("..data/cleaned/data.json")
#
# /tmp/ipython-input-1078581262.py in load_data(filename)
#       1 # Function to load the data
#       2 def load_data(filename):
# ----> 3   with open(filename,"r") as f:
#       4     data = json.load(f)
#       5   return data
#
# FileNotFoundError: [Errno 2] No such file or directory: '..data/cleaned/data.json'

# %%
data
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev Hub'}]}

# %%
type(data)
# Out:
# dict

# %%
# to display users and their connections
def display_users(data):

  print("Users and their Connections:")
  for user in data['users']:
    print(f"ID:{user['id']} - {user['name']} is friends with {user['friends']} and the liked pages are {user['liked_pages']}")

  print("\nPages Info:")
  for page in data['pages']:
    print(f"{page['id']} {page['name']}")

# to load and display
data = load_data("data.json")
display_users(data)
# Out:
# Users and their Connections:
# ID:1 - Amit is friends with [2, 3] and the liked pages are [101]
# ID:2 - Priya is friends with [1, 4] and the liked pages are [102]
# ID:3 - Rahul is friends with [1] and the liked pages are [101, 103]
# ID:4 - Sara is friends with [2] and the liked pages are [104]
#
# Pages Info:
# 101 Python Developers
# 102 Data Science Enthusiasts
# 103 AI & ML Community
# 104 Web Dev Hub
